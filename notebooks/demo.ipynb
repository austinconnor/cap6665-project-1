# %% [markdown]
# # Document-to-Markdown Demo
#
# This notebook is a lightweight companion to the Streamlit demo. The presentation path is `uv run python scripts/run_demo.py`.

# %%
from docmd.pipeline import run_page_pipeline

# Example after training:
# page = run_page_pipeline(
#     image_path='demo_samples/<sample>.png',
#     weights='models/yolo26m_detection_docaug_b8.pt',
#     output_dir='outputs/notebook_demo',
#     mode='detection',
#     device='cuda',
# )
# print(page.markdown[:1000])
